# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
# %matplotlib inline
from copy import deepcopy
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
# Importing the dataset

#http://eneskemalergin.github.io/blog//blog/Fuzzy_Clustering/

# %%
file = pd.read_csv('BSOM_DataSet_revised.csv')
data=file[['all_NBME_avg_n4', 'all_PIs_avg_n131', 'HD_final','all_irats_avg_n34','HA_final']]


print(data.shape)
data.head()
# Out:
# (115, 5)
#    all_NBME_avg_n4  all_PIs_avg_n131  HD_final  all_irats_avg_n34  HA_final
# 0           0.7700            0.6623      0.95             0.7356      0.82
# 1           0.8000            0.6107      0.84             0.6134      0.76
# 2           0.8125            0.6798      0.88             0.6762      0.90
# 3           0.9250            0.7652      0.91             0.7949      0.96
# 4           0.8550            0.6772      0.83             0.7169      0.88

# %%
# Getting the values and plotting it
d1 = data['all_NBME_avg_n4'].values
d2 = data['all_PIs_avg_n131'].values
d3 = data['HD_final'].values
d4 = data['all_irats_avg_n34'].values
d5=data['HA_final'].values
X = np.array(list(zip(d1, d2,d3,d4,d5)))

# %%
# Number of clusters
k = 3

C = np.array(data.sample(3))
print(np.array(C))

#print(Centroids)
# Out:
# [[0.8075 0.6957 0.9    0.7295 0.88  ]
#  [0.6825 0.5377 0.74   0.5511 0.78  ]
#  [0.8475 0.6914 0.83   0.7309 0.88  ]]

# %%
# Euclidean Distance Caculator
def dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %%
# To store the value of centroids when it updates
C_old = np.zeros(C.shape)
# Cluster Lables(0, 1, 2)
clusters = np.zeros(len(X))
# Error func. - Distance between new centroids and old centroids
error = dist(C, C_old, None)
# Loop will run till the error becomes zero
while error!=0:
    # Assigning each value to its closest cluster
    for i in range(len(X)):
        distances = dist(X[i], C) # distances from points to clusetr 
        
        #print('distances', distances)
        cluster = np.argmin(distances)# finding min of three clusters 
        
        #print('cluster',cluster)
        clusters[i] = cluster # saving the clusters as 0,1,2 
        #print('clusters[i]',clusters[i])
    # Storing the old centroid values
    C_old = deepcopy(C) # saving to c_old 
    #print('C_old',C_old)
    # Finding the new centroids by taking the average value
    #classified_cluster=np.array([])
    points_list=[]
    for i in range(k):
        points = [X[j] for j in range(len(X)) if clusters[j] == i]
        #print('points',points)
        #points_df=pd.DataFrame(points).append()
        
        points_list.append(points)
        
        #classified_cluster.concatenate(points)
        
        #classified_cluster.append(np.array(points))
        #print('classified_cluster',classified_cluster)
        #print(type(points))
    
    
        C[i] = np.mean(points)
        #print(' C[i]', C[i])
        error = dist(C, C_old, None)
    #points_list.append(points)
            
       
        #points_list.append(points)
    #print('points_list',points_list)
    print('error',error)
    
    
print('error',error)
    
print('points_list',points_list)

"""
#----------------------------Vizualization manually ----------------------    
    
    colors = ['r', 'g', 'b', 'y', 'c', 'm']
#fig, ax = plt.subplots()
fig = plt.figure()
ax = Axes3D(fig)
#ax.scatter(X[:, 0], X[:, 1], X[:, 2])

for i in range(k):
        points = np.array([X[j] for j in range(len(X)) if clusters[j] == i])
        ax.scatter(points[:, 0], points[:, 1],points[:, 2], s=7, c=colors[i])
ax.scatter(C[:, 0], C[:, 1], C[:, 2] ,marker='^', s=200, c='red')
    """

    
print('The updated clusters are :',C)
# Out:
# error 0.330460746145393
# error 0.07417875692086887
# error 0.012980786562629958
# error 0.0039061502141998347
# error 0.00327080263086443
# error 0.0
# error 0.0
# points_list [[array([0.925 , 0.7652, 0.91  , 0.7949, 0.96  ]), array([0.875 , 0.7352, 0.93  , 0.7128, 0.86  ]), array([0.8875, 0.7719, 0.95  , 0.8156, 0.9   ]), array([0.88  , 0.7   , 0.95  , 0.7991, 0.86  ]), array([0.84  , 0.7039, 0.83  , 0.7833, 0.9   ]), array([0.8475, 0.7063, 0.92  , 0.7927, 0.9   ]), array([0.895 , 0.7147, 0.95  , 0.7779, 0.98  ]), array([0.9125, 0.772 , 0.98  , 0.864 , 0.94  ]), array([0.86  , 0.7453, 0.92  , 0.7342, 0.92  ]), array([0.9275, 0.7967, 0.96  , 0.8131, 0.9   ]), array([0.86  , 0.7175, 0.99  , 0.7267, 0.76  ]), array([0.92  , 0.7752, 0.97  , 0.7909, 0.86  ]), array([0.9225, 0.7219, 0.86  , 0.7782, 0.84  ]), array([0.905 , 0.8001, 0.95  , 0.8035, 0.94  ]), array([0.8825, 0.7724, 0.95  , 0.7917, 0.94  ]), array([0.8675, 0.75  , 0.88  , 0.7887, 0.82  ]), array([0.8725, 0.7565, 0.86  , 0.7681, 0.9   ]), array([0.905 , 0.7453, 0.88  , 0.762 , 0.96  ]), array([0.9075, 0.757 , 0.87  , 0.801 , 0.96  ]), array([0.915 , 0.7875, 0.94  , 0.7976, 1.    ]), array([0.8925, 0.7715, 0.97  , 0.7753, 0.96  ]), array([0.8725, 0.7765, 0.84  , 0.8108, 0.9   ]), array([0.9   , 0.7167, 0.9   , 0.7813, 0.78  ]), array([0.88  , 0.7043, 0.85  , 0.7037, 0.96  ]), array([0.8625, 0.6975, 0.91  , 0.762 , 0.92  ]), array([0.905 , 0.7548, 0.98  , 0.7787, 0.88  ]), array([0.8625, 0.7425, 0.95  , 0.8044, 0.92  ]), array([0.8675, 0.672 , 0.87  , 0.7502, 0.88  ]), array([0.915 , 0.682 , 0.94  , 0.7151, 0.86  ]), array([0.8325, 0.7367, 0.94  , 0.7306, 0.88  ])], [array([0.775 , 0.6431, 0.84  , 0.6337, 0.7   ]), array([0.715 , 0.5491, 0.69  , 0.6384, 0.74  ]), array([0.74  , 0.555 , 0.74  , 0.5212, 0.7   ]), array([0.81  , 0.5585, 0.8   , 0.615 , 0.76  ]), array([0.79  , 0.6179, 0.75  , 0.6759, 0.78  ]), array([0.7775, 0.5933, 0.83  , 0.5726, 0.78  ]), array([0.74  , 0.5915, 0.7   , 0.6868, 0.7   ]), array([0.615 , 0.5038, 0.64  , 0.5312, 0.72  ]), array([0.7125, 0.5423, 0.63  , 0.6189, 0.76  ]), array([0.77  , 0.5578, 0.85  , 0.6152, 0.74  ]), array([0.74  , 0.5248, 0.73  , 0.609 , 0.72  ]), array([0.745 , 0.6245, 0.8   , 0.6102, 0.7   ]), array([0.77  , 0.6186, 0.77  , 0.6505, 0.74  ]), array([0.83  , 0.5764, 0.79  , 0.6549, 0.64  ]), array([0.7   , 0.5272, 0.54  , 0.6504, 0.66  ]), array([0.71  , 0.5136, 0.68  , 0.6427, 0.7   ]), array([0.71  , 0.512 , 0.74  , 0.6469, 0.84  ]), array([0.7075, 0.5545, 0.67  , 0.6729, 0.46  ]), array([0.815 , 0.6551, 0.69  , 0.6059, 0.64  ]), array([0.7475, 0.5793, 0.77  , 0.6579, 0.82  ]), array([0.67  , 0.5471, 0.72  , 0.5275, 0.68  ]), array([0.8075, 0.6321, 0.8   , 0.6151, 0.74  ]), array([0.7625, 0.5984, 0.74  , 0.674 , 0.78  ]), array([0.63  , 0.4248, 0.58  , 0.4922, 0.72  ]), array([0.6825, 0.5253, 0.7   , 0.5828, 0.68  ]), array([0.7425, 0.5356, 0.78  , 0.6499, 0.7   ]), array([0.78  , 0.5706, 0.74  , 0.6018, 0.74  ]), array([0.7175, 0.609 , 0.76  , 0.6223, 0.86  ]), array([0.7475, 0.5862, 0.82  , 0.6253, 0.78  ]), array([0.7725, 0.5585, 0.81  , 0.6702, 0.76  ]), array([0.77  , 0.5843, 0.9   , 0.5751, 0.78  ]), array([0.7475, 0.5808, 0.6   , 0.6199, 0.74  ]), array([0.69  , 0.5502, 0.7   , 0.6038, 0.72  ]), array([0.72  , 0.5154, 0.68  , 0.5761, 0.74  ]), array([0.7425, 0.5835, 0.72  , 0.8133, 0.7   ]), array([0.6825, 0.5377, 0.74  , 0.5511, 0.78  ]), array([0.7275, 0.6125, 0.83  , 0.6166, 0.74  ])], [array([0.77  , 0.6623, 0.95  , 0.7356, 0.82  ]), array([0.8   , 0.6107, 0.84  , 0.6134, 0.76  ]), array([0.8125, 0.6798, 0.88  , 0.6762, 0.9   ]), array([0.855 , 0.6772, 0.83  , 0.7169, 0.88  ]), array([0.7925, 0.5844, 0.9   , 0.615 , 0.78  ]), array([0.8525, 0.6467, 0.84  , 0.6878, 0.78  ]), array([0.795 , 0.6096, 0.81  , 0.6088, 0.82  ]), array([0.8375, 0.653 , 0.91  , 0.674 , 0.9   ]), array([0.8175, 0.6864, 0.91  , 0.6918, 0.92  ]), array([0.81  , 0.673 , 0.93  , 0.7364, 0.78  ]), array([0.8475, 0.6588, 0.79  , 0.7109, 0.84  ]), array([0.84  , 0.7004, 0.92  , 0.6936, 0.88  ]), array([0.8375, 0.6576, 0.86  , 0.6811, 0.88  ]), array([0.86  , 0.6161, 0.81  , 0.7007, 0.76  ]), array([0.765  ...
# The updated clusters are : [[0.845298   0.845298   0.845298   0.845298   0.845298  ]
#  [0.67783784 0.67783784 0.67783784 0.67783784 0.67783784]
#  [0.77047333 0.77047333 0.77047333 0.77047333 0.77047333]]

# %%
#------------------------- For k=3 DB index values------------------------


Si3_dist=[i for i in range(len(points_list))]

Si3_final=[]


          
for each in range(len(points_list)):
    print(each)
    
    for si in points_list[each]:
        
        Si3=dist(si, C_old[[each]]) 
        
        Si3_dist.append(Si3)
        
    Si3_= (1/len(points_list[each]))*np.sum(Si3_dist)
    
    Si3_final.append(Si3_)

print('Si3_dist',Si3_dist)
print('Si3_final',Si3_final)   
 

C3_12=dist(C_old[[0]],C_old[[1]])
print('C3_12',C3_12)
C3_13=dist(C_old[[0]],C_old[[2]])
print('C3_13',C3_13)
C3_23=dist(C_old[[1]],C_old[[2]])
print('C3_23',C3_23)




R3_12= (Si3_final[0]+Si3_final[1])/C3_12 #(S_i+S_j)/M_ij
R3_13= (Si3_final[0]+Si3_final[2])/C3_13 #(S_i+S_j)/M_ij
R3_23= (Si3_final[1]+Si3_final[2])/C3_13 #(S_i+S_j)/M_ij

max_C3_R1=max(R3_12,R3_13)
max_C3_R2=max(R3_12,R3_23)
max_C3_R3=max(R3_13,R3_23)


D3_i=max(max_C3_R1,max_C3_R2,max_C3_R3)



DB_3=(1/3)*(D3_i)
        
print('DB value for k=3 and num of data columns= 5 is ',DB_3)
# Out:
# 0
# 1
# 2
# Si3_dist [0, 1, 2, array([0.18069575]), array([0.19480779]), array([0.14834104]), array([0.18875553]), array([0.16459512]), array([0.17511294]), array([0.23059869]), array([0.19326554]), array([0.18362814]), array([0.16218663]), array([0.24254563]), array([0.17093858]), array([0.16103905]), array([0.16518244]), array([0.17176097]), array([0.12092224]), array([0.13339049]), array([0.18671707]), array([0.16551337]), array([0.20826727]), array([0.20317734]), array([0.0984053]), array([0.17573172]), array([0.23305217]), array([0.1970925]), array([0.18851623]), array([0.17052531]), array([0.20342854]), array([0.24012651]), array([0.18784473]), array([0.19845171]), array([0.15336836]), array([0.21873266]), array([0.23943927]), array([0.1783848]), array([0.24848466]), array([0.11126994]), array([0.24279573]), array([0.17912208]), array([0.24562245]), array([0.19110704]), array([0.16536418]), array([0.15845612]), array([0.21904601]), array([0.20797407]), array([0.17244992]), array([0.24424259]), array([0.25225226]), array([0.16150895]), array([0.20895929]), array([0.20380776]), array([0.20402939]), array([0.16671539]), array([0.33485505]), array([0.18115616]), array([0.19005681]), array([0.18827396]), array([0.22210327]), array([0.21600399]), array([0.21789502]), array([0.29595842]), array([0.16597836]), array([0.15553053]), array([0.20587155]), array([0.18357459]), array([0.22366061]), array([0.19365664]), array([0.21817552]), array([0.23667493]), array([0.2182856]), array([0.18507914]), array([0.27594987]), array([0.18386899]), array([0.23798173]), array([0.25267471]), array([0.23936424]), array([0.1943294]), array([0.164828]), array([0.22362481]), array([0.21267739]), array([0.19592477]), array([0.24701325]), array([0.19750679]), array([0.18922543]), array([0.14578939]), array([0.19597204]), array([0.1711469]), array([0.19342722]), array([0.2496247]), array([0.23724114]), array([0.18099804]), array([0.12941981]), array([0.15879905]), array([0.12758456]), array([0.12610614]), array([0.22942503]), array([0.16041552]), array([0.15328961]), array([0.22246449]), array([0.26640434]), array([0.17841212]), array([0.1964537]), array([0.25512972]), array([0.15143301]), array([0.24136078]), array([0.159923]), array([0.27149143]), array([0.2010921]), array([0.20629462]), array([0.23126441]), array([0.23411062]), array([0.20946459]), array([0.29254946]), array([0.40215998]), array([0.21807385])]
# Si3_final [0.28153882035483224, 0.43222497842303065, 0.5429756280474185]
# C3_12 [0.37445231]
# C3_13 [0.16731304]
# C3_23 [0.20713927]
# DB value for k=3 and num of data columns= 5 is  [1.9428663]
