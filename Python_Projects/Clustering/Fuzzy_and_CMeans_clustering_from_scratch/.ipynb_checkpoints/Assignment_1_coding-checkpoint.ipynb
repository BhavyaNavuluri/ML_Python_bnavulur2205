# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.mplot3d import Axes3D

# %%
# Loading the dataset

file=pd.read_csv('C:/Users/Bhavya N/ML_Fall19/Assignment_1/BSOM_DataSet_reorganized.csv')


df=file[['all_NBME_avg_n4', 'all_PIs_avg_n131', 'HD_final']]


print(df.head())
# Out:
#    all_NBME_avg_n4  all_PIs_avg_n131  HD_final
# 0           0.7700            0.7617      0.95
# 1           0.8000            0.7433      0.84
# 2           0.8125            0.8150      0.88
# 3           0.9250            0.8867      0.91
# 4           0.8550            0.8317      0.83

# %%
# Cleaning the dataset

df.isnull().any()

#There are no null values so the data is proper
# Out:
# all_NBME_avg_n4     False
# all_PIs_avg_n131    False
# HD_final            False
# dtype: bool

# %% [markdown]
# 1. a KMeans Clustering

# %%
# Initially the data is like this 

df.set_index('HD_final').plot(linestyle="none",figsize=(10,5), grid=True,marker="^")

# %%
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.iloc[:, 0], df.iloc[:, 1], df.iloc[:, 2])

# %%
import numpy as np
single_point = [3, 4]
points = np.arange(20).reshape((10,2))

dist = (points - single_point)**2
dist = np.sum(dist, axis=1)
dist = np.sqrt(dist)

print(dist)
# Out:
# [ 4.24264069  1.41421356  1.41421356  4.24264069  7.07106781  9.89949494
#  12.72792206 15.55634919 18.38477631 21.21320344]

# %%
# initializing the centroids

clusters = df.sample(n=3)
print('The centroids are :',clusters)

print(type(clusters))
fig = plt.figure()
ax = Axes3D(fig)
ax.scatter(df.iloc[:, 0], df.iloc[:, 1], df.iloc[:, 2])
ax.scatter(np.array(clusters.iloc[0,:]),np.array(clusters.iloc[1,:]),np.array(clusters.iloc[2,:]), marker='*', s=200, c='r')
# Out:
# The centroids are :     all_NBME_avg_n4  all_PIs_avg_n131  HD_final
# 51           0.8475            0.8183      0.83
# 40           0.8300            0.7217      0.79
# 6            0.7150            0.6717      0.69
# <class 'pandas.core.frame.DataFrame'>

# %%
total = df.shape

print(total)
# Out:
# (115, 3)

# %%
def euclidiean(featureset ,centroids ):
    
    calculated_clusters=np.linalg.norm(centroids-featureset, axis=1)
    
    classified_clusters=np.linalg.norm(centroids-featureset, axis=1).argmin()
    return calculated_clusters


categories=np.apply_along_axis(euclidiean, 1, df , clusters) 





print(categories)
"""
#print('categories',categories)

df_categories=pd.DataFrame(categories)

print(df_categories)
"""

# %%
df_categories.columns = ['clustersDistance', 'grouping']
#print(df_categories)


new_df = df_categories["clustersDistance"].str.split(",", n = 1, expand = True) 


new_df[['c1','c2','c3']] = df_categories.clustersDistance.str.split(",",expand=True)

print(new_df)

"""
# Step 2
# We now want to get rid of the secondary index
# To do this, we will make EmployeeId as a column (it can't be an index since the values will be duplicate)
new_df = new_df.reset_index([0, 'EmployeeId'])
# Step 3
# The final step is to set the column names as we want them
new_df.columns = ['EmployeeId', 'City']"""
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-107-221afe499855> in <module>()
#       6
#       7
# ----> 8 new_df[['c1','c2','c3']] = df_categories.clustersDistance.str.split(",",expand=True)
#       9
#      10 print(new_df)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3114             self._setitem_frame(key, value)
#    3115         elif isinstance(key, (Series, np.ndarray, list, Index)):
# -> 3116             self._setitem_array(key, value)
#    3117         else:
#    3118             # set column
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _setitem_array(self, key, value)
#    3136             if isinstance(value, DataFrame):
#    3137                 if len(value.columns) != len(key):
# -> 3138                     raise ValueError('Columns must be same length as key')
#    3139                 for k1, k2 in zip(key, value.columns):
#    3140                     self[k1] = value[k2]
#
# ValueError: Columns must be same length as key
