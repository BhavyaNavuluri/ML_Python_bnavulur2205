# %%
# %matplotlib inline
from copy import deepcopy
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
# %matplotlib inline
from copy import deepcopy
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
import pandas as pd
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')
from random import *

import math
# Importing the dataset

#http://eneskemalergin.github.io/blog//blog/Fuzzy_Clustering/

# %%
file = pd.read_csv('BSOM_DataSet_reorganized.csv')
data=file[['all_NBME_avg_n4', 'all_PIs_avg_n131', 'HD_final','all_irats_avg_n34']]

X=np.array(data)
print(data.shape)
data.head()

print(X.shape)
# Out:
# (115, 4)
# (115, 4)

# %%
# Number of Clusters
clusters = 3


# Number of data points
n = len(data)
print(n)


# Fuzzy parameter
fuzzifier = 2.00
# Out:
# 115

# %%
# random centroids generation
C0 = np.random.uniform(0.4,1.0,size=4)
C1 = np.random.uniform(0.6,1.0,size=4)
C2 = np.random.uniform(0.7,1.0,size=4)

Centroids=C0,C1,C2
#Centroids = np.array(list(zip(C0,C1,C2)))
print(Centroids)
# Out:
# (array([0.47225169, 0.88245672, 0.62196937, 0.78919209]), array([0.80296959, 0.92643799, 0.74721508, 0.80208172]), array([0.81727315, 0.73687708, 0.79501208, 0.82195878]))

# %%
def euc_dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

# %%
# Euclidean Distance Caculator

def dist(a,b):
        sum = 0
        for m in range(len(a)):
            for n in range(len(b)):

                sum  += ((a[m][n] - b[m][n]))**2

        ed = math.sqrt(sum)
        return ed

# %%
total_weights=[]
c_updated=[]
error = 10
c_old = Centroids

while (error > 0.3):
    
    for i in range(n):
        weights=[]# weights of points for all the clusters 
        for w in range(3):
            w0=(euc_dist(X[[i]],Centroids[w])/euc_dist(X[[i]],Centroids[0]))**fuzzifier
            #print('w0',w0)

            w1=(euc_dist(X[[i]],Centroids[w])/euc_dist(X[[i]],Centroids[1]))**fuzzifier
            #print('w1',w1)
            w2=(euc_dist(X[[i]],Centroids[w])/euc_dist(X[[i]],Centroids[2]))**fuzzifier
            #w3=(dist(X[[i]],Centroids[[w]])/dist(X[[i]],Centroids[[3]]))**fuzzifier
            #print('w2',w2)
            sum_val=w0+w1+w2
                #print('sum_val',sum_val)

                #print('sqr_sum',sqr_sum)
            finl_weights=1/sum_val
                #print('finl_weights',finl_weights)
            #total_weights.append(finl_weights)
            weights.append(finl_weights)
        total_weights.append(weights)
    #weights1_df=pd.DataFrame(total_weights)
        
        #print('total_weights',total_weights)

    weights_df=pd.DataFrame(total_weights)
    print('weights_df',weights_df)

    

    #weights_df[0] = weights_df[0].str.get(0)
    #weights_df[1] = weights_df[1].str.get(0)
    #weights_df[2] = weights_df[2].str.get(0)


    for l in range(clusters):
        for v in range(n):# n = num of data points
            product_c0=np.array(weights_df[[l]])*np.array(weights_df[[l]])*X[v]
        product_c0_df=pd.DataFrame(product_c0)
        #print('product_c0_df',product_c0_df)
        productSum_df_c0=np.array(product_c0_df.sum(axis = 0))/np.sum(weights_df[l])
        print('productSum_df_c0',productSum_df_c0)
        #c_updated.append(productSum_df_c0)
        if l==0:
            c0=productSum_df_c0
        if l==1:
            c1=productSum_df_c0
        if l==2:
            c2=productSum_df_c0
# 222    [0.05596308548434622]   [0.31128748301517994]   [0.6327494315004739]
# 223    [0.10695438141605729]   [0.22179015595539966]   [0.6712554626285431]
# 224   [0.032203004732062605]   [0.15720351759408777]   [0.8105934776738496]
# 225     [0.2115288893942647]    [0.2458347118971251]   [0.5426363987086102]
# 226    [0.04916012164540303]   [0.19981021079712002]    [0.751029667557477]
# 227     [0.0719497786116119]    [0.3448984001240695]   [0.5831518212643185]
# 228    [0.09255594079189677]   [0.22645103228974908]   [0.6809930269183542]
# 229    [0.04381428250075989]    [0.4342045118835319]   [0.5219812056157083]
#
# [230 rows x 3 columns]
# productSum_df_c0 [0.12406277 0.12179008 0.11938794 0.12406277]
# productSum_df_c0 [0.29264222 0.28728135 0.28161512 0.29264222]
# productSum_df_c0 [0.582828   0.57215126 0.56086636 0.582828  ]
# [array([0.12406277, 0.12179008, 0.11938794, 0.12406277]), array([0.29264222, 0.28728135, 0.28161512, 0.29264222]), array([0.582828  , 0.57215126, 0.56086636, 0.582828  ])]
# 4.3709524189038457e-16

# %%
clust_labels=[]
for i in range(len(weights_df)):
    labels_val= np.argmax(np.array(weights_df.iloc[i,:]))
    clust_labels.append(labels_val)
weights_df['Labels']=clust_labels  

print(weights_df['Labels'])

print(weights_df)
# Out:
# 0      2
# 1      2
# 2      2
# 3      2
# 4      2
# 5      2
# 6      2
# 7      2
# 8      2
# 9      2
# 10     2
# 11     2
# 12     2
# 13     2
# 14     2
# 15     2
# 16     2
# 17     2
# 18     2
# 19     2
# 20     2
# 21     0
# 22     2
# 23     2
# 24     2
# 25     2
# 26     2
# 27     1
# 28     1
# 29     2
#       ..
# 200    2
# 201    2
# 202    2
# 203    2
# 204    2
# 205    2
# 206    2
# 207    2
# 208    2
# 209    2
# 210    2
# 211    2
# 212    2
# 213    2
# 214    2
# 215    2
# 216    2
# 217    2
# 218    2
# 219    2
# 220    2
# 221    2
# 222    2
# 223    2
# 224    2
# 225    2
# 226    2
# 227    2
# 228    2
# 229    2
# Name: Labels, Length: 230, dtype: int64
#                            0                       1                      2  \
# 0      [0.08973977309254524]    [0.2693200449211868]   [0.6409401819862679]
# 1     [0.015052150352823644]   [0.06227598974882618]   [0.9226718598983501]
# 2      [0.04729295992748605]    [0.2930516947878356]   [0.6596553452846784]
# 3      [0.08644217959918744]   [0.45604369084585467]   [0.4575141295549578]
# 4      [0.03895966648574284]   [0.35913645604131955]   [0.6019038774729376]
# 5      [0.03455313360399475]   [0.13931911896082166]   [0.8261277474351836]
# 6      [0.18478443167235714]    [0.2511642927471795]   [0.5640512755804633]
# 7      [0.05003087924711031]    [0.1853546057367364]   [0.7646145150161533]
# 8      [0.09943659885244678]   [0.19937567393566877]   [0.7011877272118845]
# 9       [0.0672140778856439]   [0.31175491115290455]   [0.6210310109614515]
# 10     [0.04396999795559082]   [0.44584256536049954]   [0.5101874366839096]
# 11   [0.0013248816112259028]  [0.005777172413413995]   [0.9928979459753601]
# 12     [0.08374411839069883]    [0.4009406371724558]   [0.5153152444368454]
# 13     [0.03101133902453926]   [0.16565711968305466]    [0.803331541292406]
# 14      [0.0847079900560817]    [0.4232038772048131]  [0.49208813273910523]
# 15    [0.027721888824254408]   [0.08815411410798345]   [0.8841239970677621]
# 225     [0.2115288893942647]    [0.2458347118971251]   [0.5426363987086102]
# 226    [0.04916012164540303]   [0.19981021079712002]    [0.751029667557477]
# 227     [0.0719497786116119]    [0.3448984001240695]   [0.5831518212643185]
# 228    [0.09255594079189677]   [0.22645103228974908]   [0.6809930269183542]
# 229    [0.04381428250075989]    [0.4342045118835319]   [0.5219812056157083]
#
#      Labels
# 0         2
# 1         2
# 2         2
# 3         2
# 4         2
# 5         2
# 6         2
# 7         2
# 8         2
# 9         2
# 10        2
# 11        2
# 12        2
# 13        2
# 14        2
# 15        2
# 16        2
# 17        2
# 18        2
# 19        2
# 20        2
# 21        0
# 22        2
# 23        2
# 24        2
# 25        2
# 26        2
# 27        1
# 28        1
# 29        2
# ..      ...
# 200       2
# 201       2
# 202       2
# 203       2
# 204       2
# 205       2
# 206       2
# 207       2
# 208       2
# 209       2
# 210       2
# 211       2
# 212       2
# 213       2
# 214       2
# 215       2
# 216       2
# 217       2
# 218       2
# 219       2
# 220       2
# 221       2
# 222       2
# 223       2
# 224       2
# 225       2
# 226       2
# 227       2
# 228       2
# 229       2
#
# [230 rows x 4 columns]

# %%
#print(weights_df)
points_list0=[]
points_list1=[]
points_list2=[]

for i in range(len(weights_df[:-115])):
    if (weights_df.iloc[i,-1]==0):
        points_list0.append(X[i])
    if (weights_df.iloc[i,-1]==1):
        points_list1.append(X[i])
    if (weights_df.iloc[i,-1]==2):
        points_list2.append(X[i])

print('points_list0',points_list0)
print(len(points_list0))
print(len(points_list1))
print(len(points_list2))
#print('points_list1',points_list1)
#print('points_list2',points_list2)
# Out:
# points_list0 [array([0.615, 0.635, 0.64 , 0.615]), array([0.63 , 0.622, 0.58 , 0.63 ])]
# 2
# 9
# 104

# %%
###### print('points_list0',points_list0)
print('points_list1',points_list1)

print('------------------------')
print('points_list2',points_list2)
# Out:
# points_list1 [array([0.86  , 0.8783, 0.92  , 0.86  ]), array([0.9275, 0.9167, 0.96  , 0.9275]), array([0.92  , 0.9017, 0.97  , 0.92  ]), array([0.905 , 0.9183, 0.95  , 0.905 ]), array([0.8825, 0.8967, 0.95  , 0.8825]), array([0.8675, 0.87  , 0.88  , 0.8675]), array([0.905, 0.88 , 0.88 , 0.905]), array([0.9075, 0.8783, 0.87  , 0.9075]), array([0.915, 0.895, 0.94 , 0.915])]
# ------------------------
# points_list2 [array([0.77  , 0.7617, 0.95  , 0.77  ]), array([0.8   , 0.7433, 0.84  , 0.8   ]), array([0.8125, 0.815 , 0.88  , 0.8125]), array([0.925 , 0.8867, 0.91  , 0.925 ]), array([0.855 , 0.8317, 0.83  , 0.855 ]), array([0.775 , 0.7583, 0.84  , 0.775 ]), array([0.715 , 0.6717, 0.69  , 0.715 ]), array([0.7925, 0.755 , 0.9   , 0.7925]), array([0.74 , 0.695, 0.74 , 0.74 ]), array([0.875 , 0.8067, 0.93  , 0.875 ]), array([0.8525, 0.85  , 0.84  , 0.8525]), array([0.81  , 0.7383, 0.8   , 0.81  ]), array([0.8875, 0.855 , 0.95  , 0.8875]), array([0.79  , 0.7717, 0.75  , 
117, 0.83  , 0.84  ]), array([0.795 , 0.7683, 0.85  , 0.795 ]), array([0.7875, 0.82  , 0.89  , 0.7875]), array([0.77  , 0.7733, 0.9   , 0.77  ]), array([0.86 , 0.795, 0.87 , 0.86 ]), array([0.8225, 0.8033, 0.92  , 0.8225]), array([0.7875, 0.7883, 0.87  , 0.7875]), array([0.7775, 0.7633, 0.86  , 0.7775]), array([0.7475, 0.6767, 0.6   , 0.7475]), array([0.8625, 0.8517, 0.91  , 0.8625]), array([0.8375, 0.77  , 0.8   , 0.8375]), array([0.82, 0.81, 0.9 , 0.82]), array([0.88  , 0.8133, 0.71  , 0.88  ]), array([0.8275, 0.8617, 0.94  , 0.8275]), array([0.8025, 0.7717, 0.86  , 0.8025]), array([0.69  , 0.6433, 0.7   , 0.69  ]), array([0.905 , 0.8917, 0.98  , 0.905 ]), array([0.8675, 0.81  , 0.92  , 0.8675]), array([0.72  , 0.7067, 0.68  , 0.72  ]), array([0.8625, 0.8583, 0.95  , 0.8625]), array([0.8225, 0.8133, 0.81  , 0.8225]), array([0.86  , 0.8567, 0.89  , 0.86  ]), array([0.8675, 0.8483, 0.87  , 0.8675]), array([0.915, 0.85 , 0.94 , 0.915]), array([0.79  , 0.7717, 0.88  , 0.79  ]), array([0.81  , 0.7433, 0.77  , 0.81  ]), array([0.8125, 0.8167, 0.9   , 0.8125]), array([0.7425, 0.7083, 0.72  , 0.7425]), array([0.8075, 0.775 , 0.87  , 0.8075]), arr ...

# %%
points_list3=[]
points_list3.append(points_list0 )
points_list3.append(points_list1 )
points_list3.append(points_list2 )

#print(points_list3)
for i in range(len(points_list3)):
    print(points_list3[i])
# Out:
# [array([0.615, 0.635, 0.64 , 0.615]), array([0.63 , 0.622, 0.58 , 0.63 ])]
# [array([0.86  , 0.8783, 0.92  , 0.86  ]), array([0.9275, 0.9167, 0.96  , 0.9275]), array([0.92  , 0.9017, 0.97  , 0.92  ]), array([0.905 , 0.9183, 0.95  , 0.905 ]), array([0.8825, 0.8967, 0.95  , 0.8825]), array([0.8675, 0.87  , 0.88  , 0.8675]), array([0.905, 0.88 , 0.88 , 0.905]), array([0.9075, 0.8783, 0.87  , 0.9075]), array([0.915, 0.895, 0.94 , 0.915])]
# [array([0.77  , 0.7617, 0.95  , 0.77  ]), array([0.8   , 0.7433, 0.84  , 0.8   ]), array([0.8125, 0.815 , 0.88  , 0.8125]), array([0.925 , 0.8867, 0.91  , 0.925 ]), array([0.855 , 0.8317, 0.83  , 0.855 ]), array([0.775 , 0.7583, 0.84  , 0.775 ]), array([0.715 , 0.6717, 0.69  , 0.715 ]), array([0.7925, 0.755 , 0.9   , 0.7925]), array([0.74 , 0.695, 0.74 , 0.74 ]), array([0.875 , 0.8067, 0.93  , 0.875 ]), array([0.8525, 0.85  , 0.84  , 0.8525]), array([0.81  , 0.7383, 0.8   , 0.81  ]), array([0.8875, 0.855 , 0
 0.825, 0.85 , 0.88 ]), array([0.84  , 0.8117, 0.83  , 0.84  ]), array([0.795 , 0.7683, 0.85  , 0.795 ]), array([0.7875, 0.82  , 0.89  , 0.7875]), array([0.77  , 0.7733, 0.9   , 0.77  ]), array([0.86 , 0.795, 0.87 , 0.86 ]), array([0.8225, 0.8033, 0.92  , 0.8225]), array([0.7875, 0.7883, 0.87  , 0.7875]), array([0.7775, 0.7633, 0.86  , 0.7775]), array([0.7475, 0.6767, 0.6   , 0.7475]), array([0.8625, 0.8517, 0.91  , 0.8625]), array([0.8375, 0.77  , 0.8   , 0.8375]), array([0.82, 0.81, 0.9 , 0.82]), array([0.88  , 0.8133, 0.71  , 0.88  ]), array([0.8275, 0.8617, 0.94  , 0.8275]), array([0.8025, 0.7717, 0.86  , 0.8025]), array([0.69  , 0.6433, 0.7   , 0.69  ]), array([0.905 , 0.8917, 0.98  , 0.905 ]), array([0.8675, 0.81  , 0.92  , 0.8675]), array([0.72  , 0.7067, 0.68  , 0.72  ]), array([0.8625, 0.8583, 0.95  , 0.8625]), array([0.8225, 0.8133, 0.81  , 0.8225]), array([0.86  , 0.8567, 0.89  , 0.86  ]), array([0.8675, 0.8483, 0.87  , 0.8675]), array([0.915, 0.85 , 0.94 , 0.915]), array([0.79  , 0.7717, 0.88  , 0.79  ]), array([0.81  , 0.7433, 0.77  , 0.81  ]), array([0.8125, 0.8167, 0.9   , 0.8125]), array([0.7425, 0.7083, 0.72  , 0.7425]), array([0.8075, 0.775 , 0.87  , 0.8075]), array([0.6825, 0 ...

# %%
#------------------------- For k=3 DB index values------------------------

"""
def euc_dist(a, b, ax=1):
    return np.linalg.norm(a - b, axis=ax)

"""
Si3_dist=[i for i in range(len(points_list3))]

Si3_final=[]


          
for each in range(len(points_list3)):
    #print(each)
    
    for si in points_list3[each]:
        
        Si3=euc_dist(si, [c_updated[each]]) 
        
        Si3_dist.append(Si3)
        #print(Si3_dist)
    Si3_= (1/len(points_list3[each]))*np.sum(Si3_dist)
    
    Si3_final.append(Si3_)

#print('Si3_dist',Si3_dist)
#print('Si3_final',Si3_final)   
 

C3_12=euc_dist(c_updated[0],[c_updated[1]])
#print('C3_12',C3_12)
C3_13=euc_dist(c_updated[0],[c_updated[2]])
#print('C3_13',C3_13)
C3_23=euc_dist(c_updated[1],[c_updated[2]])
#print('C3_23',C3_23)




R3_12= (Si3_final[0]+Si3_final[1])/C3_12 #(S_i+S_j)/M_ij
R3_13= (Si3_final[0]+Si3_final[2])/C3_13 #(S_i+S_j)/M_ij
R3_23= (Si3_final[1]+Si3_final[2])/C3_13 #(S_i+S_j)/M_ij

max_C3_R1=max(R3_12,R3_13)
max_C3_R2=max(R3_12,R3_23)
max_C3_R3=max(R3_13,R3_23)


D3_i=max(max_C3_R1,max_C3_R2,max_C3_R3)



DB_3=(1/3)*(D3_i)
        
print('DB value for k=3 is for 4 features ',DB_3)
# Out:
# DB value for k=3 is for 4 features  [4.29483902]
